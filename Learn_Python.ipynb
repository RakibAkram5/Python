# %% [markdown]
# <a href="https://colab.research.google.com/github/RakibAkram5/Python/blob/main/Learn_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %%
# Variables in Python
x=5    # Python has no command for declearing a variable
y="Rakib" # A variable is created the moment you fist assign a value to it
print(x)
print(y)
# Out:
# 5
# Rakib

# %%
#Variables do not need to be declared with any particular type, and can even change type after they have been set.
x= "Sally"
x=6
print(x)
# Out:
# 6

# %%
x=str(3)
y=int(3)
z=float(3)
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
x,y,z="orange","Apple","Cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# Apple
# Cherry

# %%
x=y=z="Apple"
print(x)
print(y)
print(z)
# Out:
# Apple
# Apple
# Apple

# %%
x="Python is Awesome"
print(x)
# Out:
# Python is Awesome
